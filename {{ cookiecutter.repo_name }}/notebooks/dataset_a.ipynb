# %%
import os
os.chdir('C:\\Users\\user\\path_to_{{ cookiecutter.repo_name }}')

# %%
# %matplotlib inline

# %%
import pandas as pd

# %%
df = pd.read_hdf('data/processed/dataset_a.h5')

# %%
df.set_index('ts', inplace=True)

# %% [markdown]
# $\min \sum c^\intercal x$

# %%
df.plot()
